# %% [markdown]
# # Data processing

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#         Date  United States  Alabama  Alaska  Arizona  Arkansas  California  \
# 0   2003/6/1          0.509    0.598   0.349    0.351     0.907       0.419
# 1   2003/6/8          0.546    0.679   0.451    0.423     0.671       0.429
# 2  2003/6/15          0.501    0.579   0.534    0.394     0.605       0.400
# 3  2003/6/22          0.457    0.564   0.406    0.439     0.502       0.324
# 4  2003/6/29          0.357    0.459   0.554    0.402     0.519       0.349
#
#    Colorado  Connecticut  Delaware  ...  Wyoming  New England Region  \
# 0     0.315        0.477     1.478  ...    0.653               0.644
# 1     0.394        0.754     0.860  ...    0.377               0.596
# 2     0.315        0.584     0.598  ...    0.152               0.560
# 3     0.422        0.448     0.542  ...    0.377               0.451
# 4     0.336        0.371     0.923  ...    0.180               0.376
#
#    Mid-Atlantic Region  East North Central Region  West North Central Region  \
# ...

# %%
df.dtypes
# Out:
# Date                          object
# United States                float64
# Alabama                      float64
# Alaska                       float64
# Arizona                      float64
#                               ...
# South Atlantic Region        float64
# East South Central Region    float64
# West South Central Region    float64
# Mountain Region              float64
# Pacific Region               float64
# Length: 62, dtype: object

# %%
#transform str to date type

# %%
from datetime import datetime

# %%
df['Date'] = df['Date'].map(lambda x : datetime.strptime(str(x),'%Y/%m/%d'))

# %%
df.head()
# Out:
#         Date  United States  Alabama  Alaska  Arizona  Arkansas  California  \
# 0 2003-06-01          0.509    0.598   0.349    0.351     0.907       0.419
# 1 2003-06-08          0.546    0.679   0.451    0.423     0.671       0.429
# 2 2003-06-15          0.501    0.579   0.534    0.394     0.605       0.400
# 3 2003-06-22          0.457    0.564   0.406    0.439     0.502       0.324
# 4 2003-06-29          0.357    0.459   0.554    0.402     0.519       0.349
#
#    Colorado  Connecticut  Delaware  ...  Wyoming  New England Region  \
# 0     0.315        0.477     1.478  ...    0.653               0.644
# 1     0.394        0.754     0.860  ...    0.377               0.596
# 2     0.315        0.584     0.598  ...    0.152               0.560
# 3     0.422        0.448     0.542  ...    0.377               0.451
# 4     0.336        0.371     0.923  ...    0.180               0.376
#
#    Mid-Atlantic Region  East North Central Region  West North Central Region  \
# ...

# %%
#use set_index reset index

# %%
df.set_index(['Date'],inplace = True)

# %%
df.head()
# Out:
#             United States  Alabama  Alaska  Arizona  Arkansas  California  \
# Date
# 2003-06-01          0.509    0.598   0.349    0.351     0.907       0.419
# 2003-06-08          0.546    0.679   0.451    0.423     0.671       0.429
# 2003-06-15          0.501    0.579   0.534    0.394     0.605       0.400
# 2003-06-22          0.457    0.564   0.406    0.439     0.502       0.324
# 2003-06-29          0.357    0.459   0.554    0.402     0.519       0.349
#
#             Colorado  Connecticut  Delaware  District of Columbia  ...  \
# Date                                                               ...
# 2003-06-01     0.315        0.477     1.478                 0.703  ...
# 2003-06-08     0.394        0.754     0.860                 0.636  ...
# 2003-06-15     0.315        0.584     0.598                 0.625  ...
# 2003-06-22     0.422        0.448     0.542                 0.523  ...
# 2003-06-29     0.336        0.371     0.923                 0.384  ...
#
# ...

# %% [markdown]
# # Draw the plot of Illinois

# %%
df['Illinois'].plot()
plt.show()

# %% [markdown]
# # Add more states

# %%
import matplotlib.pyplot as plt
from matplotlib import style

# %%
style.use('default')
df.Illinois.plot(label = 'Illinois')
df['Idaho'].plot(label = 'Idaho')
plt.lengend(loc = 'best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-132024c075e0> in <module>
#       2 df.Illinois.plot(label = 'Illinois')
#       3 df['Idaho'].plot(label = 'Idaho')
# ----> 4 plt.lengend(loc = 'best')
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'lengend'

# %% [markdown]
# # Draw Area plot

# %%
df.Illinois.plot(kind = 'area',label = 'Illinois',color = 'gray')

# %% [markdown]
# # Conditional graphics rendering

# %%
# Select the state with the initial letter M

# %%
df[[state for state in df.columns.values if state[0] == 'M']].plot(kind = 'area')
plt.gcf().autofmt_xdate()

# %% [markdown]
# # Draw multiple subgraphs

# %%
a=list(filter(lambda x : str(x)[0] == 'M',df.columns.values))
df[a].plot(subplots = True, figsize = (15,60),layout = (3,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f030c392dd0>,
# ...
#       dtype=object)

# %% [markdown]
# # Draw heatmap to show which state has the most Severe influenza

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
plt.figure(figsize=(200,100),dpi=150)
sns.heatmap(df,annot=True,square=True,fmt='.2f')
plt.show()
